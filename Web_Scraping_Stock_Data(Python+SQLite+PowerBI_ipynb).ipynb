# %%
# !pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 62 kB 1.2 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ...

# %%
import pandas as pd
import numpy as np
import yfinance as yf
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
engine=create_engine('sqlite:///Stockdata.db')

# %%
dow=pd.read_html('https://en.wikipedia.org/wiki/Dow_Jones_Industrial_Average')

# %%
dow[1]
# Out:
#                      Company Exchange Symbol                        Industry  \
# 0                         3M     NYSE    MMM                    Conglomerate
# 1           American Express     NYSE    AXP              Financial services
# 2                      Amgen   NASDAQ   AMGN               Biopharmaceutical
# 3                      Apple   NASDAQ   AAPL          Information technology
# 4                     Boeing     NYSE     BA           Aerospace and defense
# 5                Caterpillar     NYSE    CAT         Construction and Mining
# 6                    Chevron     NYSE    CVX              Petroleum industry
# 7                      Cisco   NASDAQ   CSCO          Information technology
# 8                  Coca-Cola     NYSE     KO                  Drink industry
# 9                        Dow     NYSE    DOW               Chemical industry
# 10             Goldman Sachs     NYSE     GS              Financial services
# ...

# %%
symbols=dow[1].Symbol.to_list()
symbols
# Out:
# ['MMM',
#  'AXP',
#  'AMGN',
#  'AAPL',
#  'BA',
#  'CAT',
#  'CVX',
#  'CSCO',
#  'KO',
#  'DOW',
#  'GS',
#  'HD',
#  'HON',
#  'INTC',
#  'IBM',
#  'JNJ',
#  'JPM',
#  'MCD',
#  'MRK',
#  'MSFT',
#  'NKE',
#  'PG',
#  'CRM',
#  'TRV',
#  'UNH',
#  'VZ',
#  'V',
#  'WBA',
#  'WMT',
#  'DIS']

# %%
infos=[]

for symbol in symbols:
  inf=yf.Ticker(symbol).info
  infos.append(inf)

# %%
infos
# Out:
# [{'zip': '55144-1000',
#   'sector': 'Industrials',
#   'fullTimeEmployees': 95000,
# ...

# %%
df=pd.DataFrame(infos)

# %%
df.head()
# Out:
#           zip              sector  fullTimeEmployees  \
# 0  55144-1000         Industrials              95000
# 1       10285  Financial Services              64000
# 2  91320-1799          Healthcare              24200
# 3       95014          Technology             164000
# 4  60606-1596         Industrials             142000
#
#                                  longBusinessSummary           city  \
# 0  3M Company operates as a diversified technolog...     Saint Paul
# 1  American Express Company, together with its su...       New York
# 2  Amgen Inc. discovers, develops, manufactures, ...  Thousand Oaks
# 3  Apple Inc. designs, manufactures, and markets ...      Cupertino
# 4  The Boeing Company, together with its subsidia...        Chicago
#
#           phone state        country companyOfficers  \
# 0  651 733 1110    MN  United States              []
# 1  212 640 2000    NY  United States              []
# 2  805 447 1000    CA  United States              []
# ...

# %%
df=df.drop(columns='companyOfficers')

# %%
df.to_sql('Fundamentals',engine,index=False,if_exists='append')

# %%
pd.read_sql('Fundamentals',engine)
# Out:
#            zip                  sector  fullTimeEmployees  \
# 0   55144-1000             Industrials              95000
# 1        10285      Financial Services              64000
# 2   91320-1799              Healthcare              24200
# 3        95014              Technology             164000
# 4   60606-1596             Industrials             142000
# 5   75039-3712             Industrials             107700
# 6   94583-2324                  Energy              42595
# 7   95134-1706              Technology              83300
# 8        30313      Consumer Defensive              79000
# 9        48674         Basic Materials              35700
# 10       10282      Financial Services              49100
# 11       30339       Consumer Cyclical             500000
# 12       28202             Industrials              99000
# 13  95054-1549              Technology             121100
# 14       10504              Technology             282100
# ...

# %% [markdown]
# Connecting SQLite to powerbi requires driver
# you can download it with http://www.ch-werner.de/sqliteodbc/ and then click on sqliteodbc_w64.exe
# then go to powerbi>get data>more data>search for odbc>select SQLite3 Datasource>specify path for database>run query to load table

# %% [markdown]
# For more info refer word docs on github
